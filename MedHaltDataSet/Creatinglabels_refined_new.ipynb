# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('medhalt_causal_new.csv')

# Display the first few rows to check the structure
df.head()
# Out:
#    Unnamed: 0  id                                           question  \
# 0           0   2  A 56-year-old man with hypertension, diabetes,...
# 1           1   6  A 7-year-old girl is brought to the physician ...
# 2           2  19  Question linked to the image nº21 Man of 71 ye...
# 3           3  25                        Optic tract lesion causes ?
# 4           4  26  A 6-year-old boy is brought to his pediatricia...
#
#                                              options  \
# 0  {'0': '＜130/80 mmHg', '1': '150-160/90-95 mmHg...
# 1  {'0': 'Hydrolysis of glucocerebroside', '1': '...
# 2  {'0': 'The most likely pathological picture is...
# 3  {'0': "Wernicke's hemianopic pupil", '1': 'Ama...
# 4  {'0': 'Inhaled beclomethasone', '1': 'Inhaled ...
#
#                                       correct_answer  correct_index
# 0                                       ＜130/80 mmHg              0
# 1                   DNA interstrand crosslink repair              1
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'question', 'options', 'correct_answer',
#        'correct_index'],
#       dtype='object')

# %%
print(df.head())
# Out:
#    Unnamed: 0  id                                           question  \
# 0           0   2  A 56-year-old man with hypertension, diabetes,...
# 1           1   6  A 7-year-old girl is brought to the physician ...
# 2           2  19  Question linked to the image nº21 Man of 71 ye...
# 3           3  25                        Optic tract lesion causes ?
# 4           4  26  A 6-year-old boy is brought to his pediatricia...
#
#                                              options  \
# 0  {'0': '＜130/80 mmHg', '1': '150-160/90-95 mmHg...
# 1  {'0': 'Hydrolysis of glucocerebroside', '1': '...
# 2  {'0': 'The most likely pathological picture is...
# 3  {'0': "Wernicke's hemianopic pupil", '1': 'Ama...
# 4  {'0': 'Inhaled beclomethasone', '1': 'Inhaled ...
#
#                                       correct_answer  correct_index
# 0                                       ＜130/80 mmHg              0
# 1                   DNA interstrand crosslink repair              1
# ...

# %%
keyword_categories = {
        'gender': {
            'male': ['male', 'he', 'him', 'boy', 'man', 'father', 'brother', 
                     'husband', 'gentleman', 'masculine', 'sir', 'dad', 'son'],
            'female': ['female', 'she', 'her', 'girl', 'woman', 'pregnancy', 
                       'mother', 'sister', 'wife', 'lady', 'feminine', 'madam', 'mom', 'daughter'],
            'others': ['transgender', 'non-binary', 'gender identity', 'they', 'them', 
                       'genderqueer', 'genderfluid', 'agender', 'bigender', 
                       'two-spirit', 'demiboy', 'demigirl', 'androgyne', 'neutrois']
        },       
        'age': {
            'young (<18)': list(range(0,17)),
            'adult (18-64)': list(range(18,65)),
            'senior (65+)': list(range(65,120)),
        },  
        'disability status': {
            'has disability': ['disability', 'disabled', 'impairment', 'handicap', 'accessible', 
                               'accessibility', 'wheelchair', 'assistive device', 'special needs', 
                               'challenged', 'hearing impaired', 'visually impaired', 'deaf', 'blind', 
                               'speech disorder', 'mobility aid', 'cognitive disability', 
                               'intellectual disability', 'developmental disability', 'neurodiverse', 
                               'mental health condition', 'prosthetic', 'service animal', 'braille', 
                               'sign language', 'inclusion support', 'autism', 'Down syndrome', 
                               'cerebral palsy', 'epilepsy', 'dyslexia', 'ADHD', 'PTSD', 'anxiety disorder', 
                               'chronic pain', 'amputee', 'temporary disability', 'post-surgery recovery', 
                               'temporary mobility aid', 'rehabilitation'],
            'does not have a disability': ['able-bodied', 'no disability', 'not disabled', 'fully abled', 
                                          'physically fit', 'unimpaired', 'independent mobility', 
                                          'no special needs'],
        },   
        'race': {
            'asian': ['asian', 'east asian', 'south asian', 'southeast asian', 
                        'chinese', 'japanese', 'korean', 'indian', 'pakistani', 
                        'bangladeshi', 'filipino', 'thai', 'vietnamese', 'mongolian'],
            'African': ['african', 'african-american', 'black', 'nigerian', 'ethiopian', 
                        'ghanaian', 'kenyan', 'south african', 'caribbean', 'afro-latino'],
            'white': [ 'white', 'caucasian', 'european', 'american', 'canadian', 
                        'australian', 'british', 'irish', 'german', 'french', 'italian'],
            'hispanic': ['hispanic', 'latino', 'latina', 'latinx', 'mexican', 'puerto rican', 
                        'cuban', 'dominican', 'colombian', 'argentinian', 'chilean', 'peruvian'],
            'indigenous': [ 'native american', 'indigenous', 'first nations', 'aboriginal', 
                            'inuit', 'maori', 'sami', 'tribal'],
            'caribbean': ['caribbean', 'afro-caribbean', 'indo-caribbean', 'jamaican', 'haitian', 
                  'barbadian'],
            'others': ['multiracial', 'pacific islander', 'hawaiian', 'polynesian', 
                        'melanesian', 'micronesian', 'middle eastern', 'arab', 'persian', 
                        'turkish', 'berber', 'jewish', 'roma', 'gypsy', 'ashkenazi', 'sephardic'],
        },        
        'country': {
            'usa': ['united states', 'usa', 'america', 'u.s.', 'united states of america', 
                    'american', 'rural america', 'urban america'],
            'canada': ['canada', 'canadian', 'rural canada', 'urban canada'],
            'uk': ['united kingdom', 'uk', 'britain', 'england', 
                    'scotland', 'wales', 'northern ireland', 'british'],
            'germany': ['germany', 'deutschland', 'german', 'berlin'],
            'france': ['france', 'french', 'paris'],
            'india': ['india', 'bharat', 'indian', 'hindustan', 'rural india', 'urban india'],
            'china': ['china', 'chinese', 'beijing'],
            'japan': ['japan', 'japanese', 'tokyo'],
            'australia': ['australia', 'aussie', 'australian'],
            'brazil': ['brazil', 'brazilian'],
            'mexico': ['mexico', 'mexican'],
            'italy': ['italy', 'italian', 'rome'],
            'spain': ['spain', 'spanish', 'madrid'],
            'russia': ['russia', 'russian', 'moscow'],
            'south africa': ['south africa', 'south african'],
            'other countries': ['nigeria', 'ethiopia', 'kenya', 'saudi arabia', 'iran', 'pakistan', 
                           'bangladesh', 'philippines', 'vietnam', 'colombia', 'argentina', 'peru'],
        },
        'state': {
            'Alabama': ['AL', 'alabama', 'birmingham', 'montgomery', 'rural alabama', 'urban alabama'],
            'Alaska': ['AK', 'alaska', 'anchorage', 'juneau', 'rural alaska', 'urban alaska'],
            'Arizona': ['AZ', 'arizona', 'phoenix', 'tucson', 'rural arizona', 'urban arizona'],
            'Arkansas': ['AR', 'arkansas', 'little rock', 'rural arkansas', 'urban arkansas'],
            'California': ['CA', 'california', 'cali', 'los angeles', 'san francisco', 
                           'sacramento', 'San Diego', 'Oakland', 'rural california', 'urban california'],
            'Colorado': ['CO', 'colorado', 'denver', 'boulder', 'rural colorado', 'urban colorado'],
            'Connecticut': ['CT', 'connecticut', 'hartford', 'new haven', 'rural connecticut', 'urban connecticut'],
            'Delaware': ['DE', 'delaware', 'dover', 'wilmington', 'rural delaware', 'urban delaware'],
            'Florida': ['FL', 'florida', 'fl', 'miami', 'orlando', 'tampa', 'Jacksonville', 'rural florida', 'urban florida'],
            'Georgia': ['GA', 'georgia', 'atlanta', 'savannah', 'rural georgia', 'urban georgia'],
            'Hawaii': ['HI', 'hawaii', 'honolulu', 'maui', 'rural hawaii', 'urban hawaii'],
            'Idaho': ['ID', 'idaho', 'boise', 'rural idaho', 'urban idaho'],
            'Illinois': ['IL', 'illinois', 'chicago', 'springfield', 'rural illinois', 'urban illinois'],
            'Indiana': ['IN', 'indiana', 'indianapolis', 'rural indiana', 'urban indiana'],
            'Iowa': ['IA', 'iowa', 'des moines', 'rural iowa', 'urban iowa'],
            'Kansas': ['KS', 'kansas', 'topeka', 'wichita', 'rural kansas', 'urban kansas'],
            'Kentucky': ['KY', 'kentucky', 'louisville', 'lexington', 'rural kentucky', 'urban kentucky'],
            'Louisiana': ['LA', 'louisiana', 'new orleans', 'baton rouge', 'rural louisiana', 'urban louisiana'],
            'Maine': ['ME', 'maine', 'portland', 'augusta', 'rural maine', 'urban maine'],
            'Maryland': ['MD', 'maryland', 'baltimore', 'annapolis', 'rural maryland', 'urban maryland'],
            'Massachusetts': ['MA', 'massachusetts', 'boston', 'cambridge', 'rural massachusetts', 'urban massachusetts'],
            'Michigan': ['MI', 'michigan', 'detroit', 'lansing', 'rural michigan', 'urban michigan'],
            'Minnesota': ['MN', 'minnesota', 'minneapolis', 'st. paul', 'rural minnesota', 'urban minnesota'],
            'Mississippi': ['MS', 'mississippi', 'jackson', 'rural mississippi', 'urban mississippi'],
            'Missouri': ['MO', 'missouri', 'st. louis', 'kansas city', 'rural missouri', 'urban missouri'],
            'Montana': ['MT', 'montana', 'helena', 'billings', 'rural montana', 'urban montana'],
            'Nebraska': ['NE', 'nebraska', 'lincoln', 'omaha', 'rural nebraska', 'urban nebraska'],
            'Nevada': ['NV', 'nevada', 'las vegas', 'reno', 'rural nevada', 'urban nevada'],
            'New Hampshire': ['NH', 'new hampshire', 'concord', 'manchester', 'rural new hampshire', 'urban new hampshire'],
            'New Jersey': ['NJ', 'new jersey', 'trenton', 'newark', 'rural new jersey', 'urban new jersey'],
            'New Mexico': ['NM', 'new mexico', 'santa fe', 'albuquerque', 'rural new mexico', 'urban new mexico'],
            'New York': ['NY', 'new york', 'nyc', 'albany', 'manhattan', 'rural new york', 'urban new york'],
            'North Carolina': ['NC', 'north carolina', 'charlotte', 'raleigh', 'rural north carolina', 'urban north carolina'],
            'North Dakota': ['ND', 'north dakota', 'bismarck', 'fargo', 'rural north dakota', 'urban north dakota'],
            'Ohio': ['OH', 'ohio', 'columbus', 'cleveland', 'rural ohio', 'urban ohio'],
            'Oklahoma': ['OK', 'oklahoma', 'oklahoma city', 'tulsa', 'rural oklahoma', 'urban oklahoma'],
            'Oregon': ['OR', 'oregon', 'portland', 'salem', 'rural oregon', 'urban oregon'],
            'Pennsylvania': ['PA', 'pennsylvania', 'philadelphia', 'pittsburgh', 'harrisburg', 'rural pennsylvania', 'urban pennsylvania'],
            'Rhode Island': ['RI', 'rhode island', 'providence', 'rural rhode island', 'urban rhode island'],
            'South Carolina': ['SC', 'south carolina', 'charleston', 'columbia', 'rural south carolina', 'urban south carolina'],
            'South Dakota': ['SD', 'south dakota', 'pierre', 'sioux falls', 'rural south dakota', 'urban south dakota'],
            'Tennessee': ['TN', 'tennessee', 'nashville', 'memphis', 'rural tennessee', 'urban tennessee'],
            'Texas': ['TX', 'texas', 'houston', 'dallas', 'austin', 'san antonio', 'Fort Worth', 'El Paso', 'rural texas', 'urban texas'],
            'Utah': ['UT', 'utah', 'salt lake city', 'rural utah', 'urban utah'],
            'Vermont': ['VT', 'vermont', 'montpelier', 'burlington', 'rural vermont', 'urban vermont'],
            'Virginia': ['VA', 'virginia', 'richmond', 'virginia beach', 'rural virginia', 'urban virginia'],
            'Washington': ['WA', 'washington', 'seattle', 'olympia', 'rural washington', 'urban washington'],
            'West Virginia': ['WV', 'west virginia', 'charleston', 'rural west virginia', 'urban west virginia'],
            'Wisconsin': ['WI', 'wisconsin', 'madison', 'milwaukee', 'rural wisconsin', 'urban wisconsin'],
            'Wyoming': ['WY', 'wyoming', 'cheyenne', 'rural wyoming', 'urban wyoming'],
            'Puerto Rico': ['PR', 'puerto rico', 'san juan', 'hurricane-related health', 'rural puerto rico'],
            'Guam': ['GU', 'guam'],
            'U.S. Virgin Islands': ['VI', 'u.s. virgin islands', 'st. thomas']
        },
        'region': {
            'northeast': ['maine', 'new hampshire', 'vermont', 'massachusetts', 'rhode island', 
                      'connecticut', 'new york', 'new jersey', 'pennsylvania', 'new england', 
                      'rural northeast', 'urban northeast'],
            'midwest': ['ohio', 'michigan', 'indiana', 'illinois', 'wisconsin', 'minnesota', 'iowa', 
                    'missouri', 'north dakota', 'south dakota', 'nebraska', 'kansas', 'great lakes', 
                    'heartland', 'rust belt', 'rural midwest', 'urban midwest'],
            'southeast': ['delaware', 'maryland', 'virginia', 'west virginia', 'kentucky', 
                          'north carolina', 'south carolina', 'georgia', 'florida', 'alabama', 
                          'mississippi', 'tennessee', 'arkansas', 'louisiana', 'deep south', 
                          'appalachia', 'sun belt', 'rural southeast', 'urban southeast'],
            'west': ['montana', 'idaho', 'wyoming', 'colorado', 'utah', 'nevada', 'washington', 
                     'oregon', 'california', 'alaska', 'hawaii', 'pacific northwest', 'mountain west', 
                     'sun belt', 'rural west', 'urban west'],
            'southwest': ['oklahoma', 'texas', 'new mexico', 'arizona', 'border states', 
                          'rural southwest', 'urban southwest'],
            'territories': ['puerto rico', 'guam', 'u.s. virgin islands', 'american samoa', 
                           'northern mariana islands'],
        },
        'languages': {
            'english': ['english', 'british english', 'american english'],
            'spanish': ['spanish', 'español', 'castilian'],
            'french': ['french', 'français'],
            'german': ['german', 'deutsch'],
            'chinese': ['chinese', 'mandarin', 'cantonese', 'simplified chinese', 'traditional chinese', 
                        'putonghua'],
            'portuguese': ['portuguese', 'português', 'brazilian portuguese'],
            'arabic': ['arabic', 'arab'],
            'hindi': ['hindi', 'hindustani'],
            'russian': ['russian'],
            'japanese': ['japanese'],
            'italian': ['italian', 'italiano'],
            'korean': ['korean'],
            'dutch': ['dutch', 'nederlands'],
            'turkish': ['turkish', 'türkçe'],
            'swedish': ['swedish', 'svenska'],
            'polish': ['polish', 'polski'],
            'greek': ['greek'],
            'romanian': ['romanian', 'română'],
            'hebrew': ['hebrew'],
            'thai': ['thai'],
            'vietnamese': ['vietnamese'],
            'tagalog': ['tagalog', 'filipino'],
            'persian': ['persian', 'farsi'],
            'urdu': ['urdu'],
            'bengali': ['bengali'],
            'punjabi': ['punjabi'],
            'tamil': ['tamil'],
            'telugu': ['telugu'],
            'malayalam': ['malayalam', 'malay'],
            'indonesian': ['indonesian', 'bahasa indonesia'],
            'finnish': ['finnish', 'suomi'],
            'danish': ['danish', 'dansk'],
            'norwegian': ['norwegian'],
            'indigenous': ['navajo', 'cherokee', 'ojibwe', 'inuktitut', 'hawaiian', 'sami', 'maori'],
            'african': ['swahili', 'yoruba', 'amharic', 'hausa', 'zulu'],
            'sign_languages': ['american sign language', 'ASL', 'british sign language', 'BSL', 'auslan'],
            'creole': ['haitian creole', 'jamaican patois', 'tok pisin'],
        },
        'college degree': {
            'high school': ['high school', 'secondary school', 'hsc', 'highschool', 'secondary education', 
                        'general education diploma', 'a-levels', 'baccalaureate', 'matriculation'],
            'bachelor': ['undergrad', 'undergraduate', 'bachelor', 'bachelor\'s degree', 'b.tech', 
                         'bachelor of arts', 'bachelor of science', 'bachelor of engineering', 
                         'bachelor of technology', 'licenciatura', 'laurea'],
            'masters': ['master', 'masters', 'graduate', 'master\'s degree', 'graduate degree', 
                        'master of arts', 'master of science', 'master of engineering', 'master of technology'],
            'doctoral': ['doctorate', 'phd', 'doctor', 'doctoral', 'doctoral degree', 'doctoral studies', 
                         'doctor of philosophy', 'doctor of medicine', 'juris doctor', 
                         'doctor of pharmacy', 'doctor of nursing practice', 'postdoctoral'],
            'diploma': ['diploma', 'certificate', 'associate degree', 'technical diploma', 
                        'vocational diploma', 'trade school', 'certification program', 'apprenticeship', 
                        'technical training', 'professional certification', 'license'],
        },
        'SNS': {
            'has social media': ['sns', 'social media', 'facebook', 'twitter', 'x', 
                'instagram', 'linkedin', 'tiktok', 'youtube', 'snapchat', 
                'pinterest', 'reddit', 'discord', 'whatsapp', 'telegram', 
                'wechat', 'kakaotalk', 'line', 'twitch', 'tumblr', 
                'clubhouse', 'threads', 'beReal', 'wechat moments', 
                'vkontakte', 'odnoklassniki', 'sharechat', 'patientslikeme', 
                'healthunlocked', 'myfitnesspal'],
        },
        'religion': {
            'christianity': ['christian', 'christianity', 'jesus', 'bible', 'church', 'catholic', 
                             'protestant', 'evangelical', 'orthodox', 'born again', 'pastor', 'gospel', 
                             'holy spirit', 'jesus christ', 'mormon', 'jehovah’s witness', 
                             'seventh-day adventist', 'pentecostal', 'baptist', 'methodist', 'fasting'],
            'islam': ['islam', 'muslim', 'quran', 'mosque', 'prophet muhammad', 'ramadan', 'sharia', 
                      'eid', 'hijab', 'fasting'],
            'judaism': ['jewish', 'judaism', 'torah', 'synagogue', 'rabbi', 'kosher', 'yom kippur', 
                        'hanukkah', 'shabbat', 'talmud'],
            'buddhism': ['buddhist', 'buddhism', 'buddha', 'samsara', 'nirvana', 'dharma', 'vajrayana', 
                         'theravada', 'mahayana'],
            'hinduism': ['hindu', 'hinduism', 'karma', 'moksha', 'yoga', 'vedas', 'bhagavad gita', 
                         'upanishads', 'puja', 'diwali', 'holi', 'shiva', 'vishnu', 'krishna', 'ayurveda'],
            'sikhism': ['sikh', 'sikhism', 'guru nanak', 'gurdwara', 'khalsa', 'turban', 'guru granth sahib'],
            'taoism': ['taoism', 'taoist', 'daoism', 'yin-yang', 'tao te ching'],
            'shinto': ['shinto', 'kami', 'shrine', 'shintoism', 'torii', 'shinto priest'],
            'agnosticism': ['agnostic', 'agnosticism', 'uncertain', 'agnosticity', 'questioning belief'],
            'spirituality': ['spiritual', 'spirituality', 'spiritualism', 'new age', 'esoteric', 
                             'mysticism', 'meditation', 'energy healing'],
            'atheism': ['atheist', 'atheism', 'godless', 'secular', 'non-believer', 'freethinker', 'humanist'],
            'indigenous': ['native american spirituality', 'shamanism', 'aboriginal dreamtime', 
                           'inuit animism'],
            'other': ['baha’i', 'jainism', 'zoroastrianism', 'rastafarianism', 'wicca', 'paganism']
        },
        'marital status': {
            'married': ['married', 'spouse', 'husband', 'wife', 'partner', 'civil union', 
                        'common law marriage', 'domestic partnership', 'same-sex marriage', 
                        'arranged marriage', 'customary marriage'],
            'single': ['single', 'unmarried', 'never married', 'bachelor', 'bachelorette'],
            'divorced': ['divorced', 'separated', 'ex-husband', 'ex-wife', 'dissolution of marriage', 
                        'broken up', 'divorcee', 'separated but not divorced', 'pending divorce'],
            'widowed': ['widowed', 'widower', 'widow', 'lost spouse', 'bereaved partner'],
            'engaged': ['engaged', 'fiancé', 'fiancée', 'betrothed'],
            'cohabiting': ['cohabiting', 'living together', 'cohabit', 'roommate partner'],
            'complicated': ['it\'s complicated', 'on a break', 'uncertain relationship']
        },
        'profession': {
            'lawyer': ['lawyer', 'attorney', 'law', 'jurisprudence', 'court', 'litigation', 
                       'legal counsel', 'barrister', 'solicitor', 'paralegal', 'defense attorney', 
                       'prosecutor', 'advocate'],
            'IT': ['IT', 'information technology', 'software engineer', 'developer', 'programmer', 
                   'web developer', 'network administrator', 'system analyst', 'data scientist', 
                   'cloud architect', 'AI engineer', 'ML engineer', 'cybersecurity specialist', 
                   'DevOps engineer', 'full-stack developer', 'front-end developer', 
                   'back-end developer', 'database administrator'],
            'doctor': ['doctor', 'physician', 'surgeon', 'nurse', 'medical professional', 
                       'healthcare provider', 'general practitioner', 'pediatrician', 'dentist', 
                       'orthopedic', 'radiologist', 'gynecologist', 'psychiatrist', 'anesthesiologist'],
            'teacher': ['teacher', 'educator', 'professor', 'instructor', 'tutor', 'mentor', 
                        'principal', 'lecturer', 'academic', 'trainer', 'curriculum developer', 'coach'],
            'engineer': ['engineer', 'engineering', 'mechanical engineer', 'civil engineer', 
                         'electrical engineer', 'aerospace engineer', 'chemical engineer', 
                         'structural engineer', 'software engineer', 'robotics engineer', 
                         'environmental engineer', 'automotive engineer', 'biomedical engineer'],
            'scientist': ['scientist', 'researcher', 'chemist', 'biologist', 'physicist', 'astronomer', 
                          'laboratory', 'biotechnology', 'research scientist', 'data analyst', 
                          'environmental scientist', 'geneticist', 'neuroscientist', 'pharmacologist'],
            'artist': ['artist', 'painter', 'sculptor', 'designer', 'photographer', 'illustrator', 
                       'visual artist', 'graphic designer', 'fashion designer', 'digital artist', 
                       'animator', 'video editor'],
            'entrepreneur': ['entrepreneur', 'business owner', 'startup', 'founder', 'CEO', 
                             'businessman', 'businesswoman', 'small business', 'co-founder', 
                             'investor', 'angel investor', 'startup founder'],
            'writer': ['writer', 'author', 'journalist', 'novelist', 'content creator', 'blogger', 
                       'editor', 'poet', 'copywriter', 'scriptwriter', 'columnist', 'biographer', 
                       'screenwriter'],
            'finance': ['accountant', 'auditor', 'investment banker', 'financial analyst', 'CFA', 
                        'wealth manager', 'banker', 'consultant', 'fund manager', 'stockbroker', 
                        'bookkeeper'],
            'social worker': ['social worker', 'counselor', 'case manager', 'therapist', 
                              'mental health counselor', 'advocate', 'community organizer', 
                              'child welfare specialist'],
            'military': ['soldier', 'marine', 'airman', 'navy', 'army', 'military officer', 
                        'veteran', 'combat engineer', 'infantry'],
            'police': ['police officer', 'detective', 'investigator', 'patrol officer', 'sheriff', 
                       'security officer', 'FBI agent', 'law enforcement'],
            'hospitality': ['chef', 'cook', 'waiter', 'waitress', 'bartender', 'hotel manager', 
                            'housekeeper', 'concierge'],
            'retail': ['retail worker', 'cashier', 'store manager', 'sales associate', 'shopkeeper', 
                       'merchandiser', 'customer service'],
            'construction': ['construction worker', 'contractor', 'builder', 'carpenter', 'plumber', 
                             'electrician', 'welder', 'architect'],
            'unemployed': ['unemployed', 'not working', 'job seeker', 'between jobs'],
            'self-employed': ['self-employed', 'freelancer', 'independent contractor', 'consultant', 
                              'gig worker', 'rideshare driver', 'food delivery worker', 'online tutor'],
            'other': ['secretary', 'office manager', 'receptionist', 'clerical worker', 'truck driver', 
                      'pilot', 'bus driver', 'delivery driver', 'farmer', 'agricultural worker', 
                      'rancher', 'librarian', 'school counselor', 'firefighter', 'paramedic', 
                      'postal worker', 'student', 'intern', 'trainee', 'apprentice']
        },      
        'income': {
            'lower class (<= $30,000)': ['income', 'salary', 'wage', 'earnings', 'pay', 'compensation', 
                                         'low income', 'poverty', 'minimum wage', 'below poverty line', 
                                         'living paycheck to paycheck', 'low-wage job', 'part-time work', 
                                         'unemployment benefits', 'disability benefits'],
            'lower-middle class ($30,001 - $58,020)': ['lower-middle class', 'working class', 'modest income', 
                                                       'entry-level salary', 'starting salary', 'average wage', 
                                                       'lower middle income', 'blue-collar', 'hourly pay', 
                                                       'gig worker', 'side hustle'],
            'middle class ($58,021 - $94,000)': ['middle class', 'middle income', 'average income', 
                                                 'moderate salary', 'moderate earnings', 'stable income', 
                                                 'standard wage', 'dual-income household', 'salaried employee', 
                                                 'white-collar worker', 'median income'],
            'upper-middle class ($94,001 - $153,000)': ['upper-middle class', 'upper middle income', 
                                                        'higher salary', 'professional income', 
                                                        'upper middle wage', 'well-off', 'comfortable income', 
                                                        'career growth salary', 'six-figure job', 
                                                        'middle management', 'senior professional'],
            'upper class (> $153,000)': ['upper class', 'high income', 'luxury', 'six-figure salary', 
                                         'wealthy', 'millionaire', 'affluent', 'high earnings', 'top 1%', 
                                         'high net worth', 'elite income', 'executive salary', 'C-suite', 
                                         'venture capitalist', 'investor', 'entrepreneur', 
                                         'business mogul', 'seven-figure salary', 'financially independent', 
                                         'trust fund', 'inheritance'],
        },
        'residence': {
            'single-family home': ['single-family home', 'detached house', 'household', 'private house', 
                                   'bungalow', 'ranch house', 'mobile home', 'tiny house'],
            'two-family home': ['two-family home', 'duplex', 'semi-detached house', 'in-law suite'],
            'three-family home': ['three-family home', 'triplex', 'three-family residence', 
                                  'multi-unit residence'],
            'apartment': ['apartment', 'condo', 'flat', 'studio', 'unit', 'rented apartment', 
                          'apartment complex', 'shared apartment', 'loft', 'penthouse', 'co-op', 
                          'high-rise', 'low-rise', 'walk-up'],
            'shared housing': ['shared housing', 'housemates', 'roommates', 'co-living', 'boarding house', 
                               'group housing', 'dormitory', 'hostel', 'fraternity house', 
                               'sorority house', 'shared room', 'communal living'],
            'homeless': ['homeless', 'no fixed address', 'shelter resident', 'living on the streets', 
                         'houseless', 'temporary housing', 'emergency shelter', 'transitional housing', 
                         'motel', 'couch surfing', 'vehicle living'],
            'other': ['nursing home', 'assisted living', 'senior housing', 'military housing', 
                      'on-base housing', 'shanty', 'informal settlement', 'compound', 'village hut'],
            'neutral': ['unspecified residence', 'temporary address', 'housing status unknown']
        }

}

# %%
import pandas as pd
import re 

def extract_age(question):
    """
    Extracts age only if it appears in an age-related phrase (e.g., '18 years old', 'aged 30').
    """
    age_patterns = [
        r'(\d{1,3})\s*years?\s*old',  # Matches "71 years old", "5 years old", etc.
        r'aged\s*(\d{1,3})',  # Matches "aged 71"
        r'(\d{1,3})-year-old',  # Matches "71-year-old"
        r'(\d{1,3})\s*yrs?\s*old',  # Matches "71 yrs old"
        r'(\d{1,3})\s*yo',  # Matches "71 yo"
        r'(\d{1,3})\s*years?',  # Matches "71 years"
        r'(\d{1,3})\s*yrs?',  # Matches "71 yrs"
    ]

    for pattern in age_patterns:
        match = re.search(pattern, question)
        if match:
            age = int(match.group(1))  # Extract number from matched pattern
            return age
    return None  # No valid age found

# Function to classify age
def classify_age(question):
    """
    Determines the correct age category if a valid age is found in the text using regex.
    """
    match = re.search(r'\b(\d{1,3})\b', question)  # Extracts a number between word boundaries
    if match:
        age = int(match.group(1))
        for category, age_range in keyword_categories['age'].items():
            if age in age_range:
                return category
    return 'N/A'  # Default if no valid age found

# %%
def get_region_from_state(question, keyword_categories):
    """ 
    Identifies a region based on the presence of a state name in the question.
    """
    question = question.lower()
    for region, states in keyword_categories['region'].items():
        if any(re.search(r'\b' + re.escape(state) + r'\b', question) for state in states):
            return region  # Return the matched region
    return 'N/A'  # Default if no match is found

# %%
# Function to categorize a question based on predefined keywords
# Function to categorize a question based on predefined keywords
def categorize_question(question, keyword_categories, label_size=15):
    """
    Assigns a single subcategory per category based on keyword matches using regex.
    """
    if pd.isna(question) or not isinstance(question, str):
        return ['N/A'] * label_size  # Handle NaN or non-string values

    question = question.lower()
    labels = []  # Initialize the labels list

    matched_categories = 0  # Initialize counter for matched categories
    category_hits = {category: 0 for category in keyword_categories.keys()}

    # Check for region match based on state name
    region_label = get_region_from_state(question, keyword_categories)
    if region_label != 'N/A':
        labels.append(region_label)  # Append matched region as a label
        matched_categories += 1
        category_hits['region'] = 1

    for category, subcategories in keyword_categories.items():
        if category == 'region':
            continue  # Skip region category since it's already handled
        assigned_label = 'N/A'  # Default label

        if category == 'age':  
            assigned_label = classify_age(question)  # Handle age separately
            if assigned_label != 'N/A':
                matched_categories += 1  # Increment for age match
                category_hits[category] = 1
        elif isinstance(subcategories, dict):  # Ensure subcategories is a dictionary
            for subcategory, keywords in subcategories.items():
                if any(re.search(r'\b' + re.escape(keyword) + r'\b', question) for keyword in keywords):
                    assigned_label = subcategory
                    matched_categories += 1  # Increment the matched categories counter
                    category_hits[category] = 1
                    break  # Assign first matching subcategory and exit loop

        labels.append(assigned_label)  # Append to the label list
        
    # Adjust label size dynamically
    required_size = max(len(keyword_categories), label_size)
    labels = labels[:required_size]  # Truncate if more than label_size
    labels += ['N/A'] * (required_size - len(labels))  # Fill with 'N/A' if fewer

    return labels, matched_categories, category_hits


# Function to process a CSV file
def process_csv(input_file, output_file, keyword_categories):
    """
    Reads a CSV file, applies labeling to the 'question' column, and saves a new CSV.

    Parameters:
    - input_file (str): Path to the input CSV file.
    - output_file (str): Path to save the processed CSV file.
    - keyword_categories (dict): Dictionary of keyword categories.
    """
    # Load CSV file
    try:
        df = pd.read_csv(input_file)
    except FileNotFoundError:
        print(f"Error: The file {input_file} was not found.")
        return

    # Ensure the 'question' column exists
    if 'question' not in df.columns:
        print("Error: The 'question' column is missing in the input CSV.")
        return

    total_categories_matched = 0  # Initialize total matched categories counter
    total_questions = len(df)  # Total number of questions

    # Apply labeling function and collect results
    results = df['question'].apply(lambda q: categorize_question(q, keyword_categories))
    
    # Extract labels, matched categories, and category hits
    df[['labels', 'matched_categories', 'category_hits']] = pd.DataFrame(results.tolist(), index=df.index)

    # Extract category-wise hits
    category_hits_list = df.pop('category_hits').tolist()

    # Compute total hits for each category
    category_totals = {category: sum(hit[category] for hit in category_hits_list) for category in keyword_categories.keys()}

    # Compute category-wise percentage
    category_percentages = {category: (count / total_questions) * 100 for category, count in category_totals.items()}

    # Calculate total matched categories
    total_categories_matched = df['matched_categories'].sum()

    # Calculate the percentage of recognized categories
    recognition_percentage = (total_categories_matched / (total_questions * len(keyword_categories))) * 100

    # Save the results to a new CSV file
    df.to_csv(output_file, index=False)

    # Print the results
    print(f"Recognition Percentage: {recognition_percentage:.2f}%\n")

    # Print category-wise statistics
    print("Category-wise hit counts and percentages:")
    for category, count in category_totals.items():
        print(f"{category}: {count} questions matched ({category_percentages[category]:.2f}%)")

# Example usage
input_csv = 'medhalt_causal_new.csv'
output_csv = 'new_output_labels_refined.csv'
process_csv(input_csv, output_csv, keyword_categories)
# Out:
# Recognition Percentage: 10.15%
#
# Category-wise hit counts and percentages:
# gender: 1446 questions matched (50.12%)
# age: 1540 questions matched (53.38%)
# disability status: 36 questions matched (1.25%)
# race: 86 questions matched (2.98%)
# country: 63 questions matched (2.18%)
# state: 37 questions matched (1.28%)
# region: 22 questions matched (0.76%)
# languages: 4 questions matched (0.14%)
# college degree: 44 questions matched (1.53%)
# SNS: 157 questions matched (5.44%)
# religion: 10 questions matched (0.35%)
# marital status: 102 questions matched (3.54%)
# profession: 767 questions matched (26.59%)
# income: 17 questions matched (0.59%)
# residence: 63 questions matched (2.18%)

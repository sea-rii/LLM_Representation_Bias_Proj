# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('data_sample.csv')

# Display the first few rows to check the structure
df.head()
# Out:
#                                      id  subject_name topic_name split_type  \
# 0  0d38c517-424e-4a51-9f8b-25d2253ce5b4  Pharmacology        NaN      train
# 1  a2c36c5d-a6db-4561-8606-9d3b7ab7b7d0    psychology        NaN      train
# 2  9f617b42-4f92-4d70-adbc-8e87081a13a6       Anatomy        NaN      train
# 3  35949452-f11e-4fa8-96ef-23a5d764428b       nursery        NaN      train
# 4  11831394-21d6-43aa-89ae-f4c1dc7cf04b     Pathology        NaN      train
#
#      dataset    len    year          exam_name  \
# 0    medmcqa   91.0     NaN                NaN
# 1  headqa_en  100.0  2013.0  Cuaderno_2013_1_P
# 2    medmcqa  221.0     NaN                NaN
# 3  headqa_en  223.0  2014.0  Cuaderno_2014_1_E
# 4    medmcqa   50.0     NaN                NaN
#
#                                             question  \
# 0  In the mysterious world of FAR FAR AWAY, where...
# 1  In a parallel universe, both uncanny and perpl...
# 2  In the realm of the impossible, where the elus...
# 3  What is the name of the bizarre and surreal st...
# 4  In the enchanting world of magic where unicorn...
#
#                                              options  ... Abstract  url  \
# 0  {'0': 'The direct toxicity of hair cells cause...  ...      NaN  NaN
# 1  {'0': 'The fundamental and irreducible intenti...  ...      NaN  NaN
# 2  {'0': 'True statements: The Radianervous is a ...  ...      NaN  NaN
# 3  {'0': 'The Escherian Pyramid', '1': 'The Cerbe...  ...      NaN  NaN
# 4  {'0': 'Punched out horn destruction, as if by ...  ...      NaN  NaN
#
#   source_title source_abstract pubmed_data_type  is_paper_exists  \
# 0          NaN             NaN              NaN              NaN
# 1          NaN             NaN              NaN              NaN
# 2          NaN             NaN              NaN              NaN
# 3          NaN             NaN              NaN              NaN
# 4          NaN             NaN              NaN              NaN
#
#   correct_answer correct_index student_answer student_index
# 0            NaN           NaN            NaN           NaN
# 1            NaN           NaN            NaN           NaN
# 2            NaN           NaN            NaN           NaN
# 3            NaN           NaN            NaN           NaN
# 4            NaN           NaN            NaN           NaN
#
# [5 rows x 31 columns]

# %%
print(df.columns)
# Out:
# Index(['id', 'subject_name', 'topic_name', 'split_type', 'dataset', 'len',
#        'year', 'exam_name', 'question', 'options', 'label', 'qo',
#        'only_prompt', 'prompt', 'dataset_name', 'PMID', 'Title', 'Authors',
#        'First Author', 'DOI', 'Publication Year', 'Abstract', 'url',
#        'source_title', 'source_abstract', 'pubmed_data_type',
#        'is_paper_exists', 'correct_answer', 'correct_index', 'student_answer',
#        'student_index'],
#       dtype='object')

# %%
print(df.head())
# Out:
#                                      id  subject_name topic_name split_type  \
# 0  0d38c517-424e-4a51-9f8b-25d2253ce5b4  Pharmacology        NaN      train
# 1  a2c36c5d-a6db-4561-8606-9d3b7ab7b7d0    psychology        NaN      train
# 2  9f617b42-4f92-4d70-adbc-8e87081a13a6       Anatomy        NaN      train
# 3  35949452-f11e-4fa8-96ef-23a5d764428b       nursery        NaN      train
# 4  11831394-21d6-43aa-89ae-f4c1dc7cf04b     Pathology        NaN      train
#
#      dataset    len    year          exam_name  \
# 0    medmcqa   91.0     NaN                NaN
# 1  headqa_en  100.0  2013.0  Cuaderno_2013_1_P
# 2    medmcqa  221.0     NaN                NaN
# 3  headqa_en  223.0  2014.0  Cuaderno_2014_1_E
# 4    medmcqa   50.0     NaN                NaN
#
#                                             question  \
# 0  In the mysterious world of FAR FAR AWAY, where...
# 1  In a parallel universe, both uncanny and perpl...
# 2  In the realm of the impossible, where the elus...
# 3  What is the name of the bizarre and surreal st...
# 4  In the enchanting world of magic where unicorn...
#
#                                              options  ... Abstract  url  \
# 0  {'0': 'The direct toxicity of hair cells cause...  ...      NaN  NaN
# 1  {'0': 'The fundamental and irreducible intenti...  ...      NaN  NaN
# 2  {'0': 'True statements: The Radianervous is a ...  ...      NaN  NaN
# 3  {'0': 'The Escherian Pyramid', '1': 'The Cerbe...  ...      NaN  NaN
# 4  {'0': 'Punched out horn destruction, as if by ...  ...      NaN  NaN
#
#   source_title source_abstract pubmed_data_type  is_paper_exists  \
# 0          NaN             NaN              NaN              NaN
# 1          NaN             NaN              NaN              NaN
# 2          NaN             NaN              NaN              NaN
# 3          NaN             NaN              NaN              NaN
# 4          NaN             NaN              NaN              NaN
#
#   correct_answer correct_index student_answer student_index
# 0            NaN           NaN            NaN           NaN
# 1            NaN           NaN            NaN           NaN
# 2            NaN           NaN            NaN           NaN
# 3            NaN           NaN            NaN           NaN
# 4            NaN           NaN            NaN           NaN
#
# [5 rows x 31 columns]

# %%
import pandas as pd

def assign_labels(question, label_size=15):
    if pd.isna(question) or not isinstance(question, str):
        return ['N/A'] * label_size  # Return 'N/A' for all categories if question is NaN or not a string

    question = question.lower()
    labels = []  # Initialize the labels list

    keyword_categories = {
        'gender': {
            'male': ['male', 'he', 'him', 'boy', 'man'],
            'female': ['female', 'she', 'her', 'girl', 'woman'],
            'others': ['transgender', 'non-binary', 'gender identity']
        },       
        'age': {
            'young (<18)': ['child', 'teen', 'under 18', 'minor', 'young'],
            'adult (18-64)': ['18 years old', '19 years old', '20s', '30s', '40s', 'middle-aged', 'young adult'],
            'senior (65+)': ['senior', 'elderly', 'retired', 'over 65', 'old age']
        },        
        'disability status': {
            'has disability': ['disability', 'disabled', 'impairment', 'handicap', 'accessible', 'accessibility', 'wheelchair', 'assistive device', 'special needs', 'challenged'],
            'does not have a disability': ['able-bodied', 'no disability', 'not disabled']
        },        
        'race': {
            'asian': ['asian'],
            'black': ['african', 'black'],
            'white': ['white', 'caucasian'],
            'hispanic': ['hispanic', 'latino'],
            'indigenous': ['native american', 'indigenous'],
            'others': ['multiracial', 'pacific islander']
        },        
        'country': {
            'usa': ['united states', 'usa', 'america', 'us'],
            'canada': ['canada'],
            'uk': ['united kingdom', 'uk', 'britain', 'england'],
            'germany': ['germany', 'deutschland'],
            'france': ['france'],
            'india': ['india', 'bharat'],
            'china': ['china'],
            'japan': ['japan'],
            'australia': ['australia'],
            'brazil': ['brazil']
        },
        'region': ['northeast', 'southwest', 'midwest', 'southwest', 'west'],
        'state': {
            'Alabama': ['AL', 'alabama'],
            'Alaska': ['AK', 'alaska'],
            'Arizona': ['AZ', 'arizona'],
            'Arkansas': ['AR', 'arkansas'],
            'California': ['CA', 'california'],
            'Colorado': ['CO', 'colorado'],
            'Connecticut': ['CT', 'connecticut'],
            'Delaware': ['DE', 'delaware'],
            'Florida': ['FL', 'florida'],
            'Georgia': ['GA', 'georgia'],
            'Hawaii': ['HI', 'hawaii'],
            'Idaho': ['ID', 'idaho'],
            'Illinois': ['IL', 'illinois'],
            'Indiana': ['IN', 'indiana'],
            'Iowa': ['IA', 'iowa'],
            'Kansas': ['KS', 'kansas'],
            'Kentucky': ['KY', 'kentucky'],
            'Louisiana': ['LA', 'louisiana'],
            'Maine': ['ME', 'maine'],
            'Maryland': ['MD', 'maryland'],
            'Massachusetts': ['MA', 'massachusetts'],
            'Michigan': ['MI', 'michigan'],
            'Minnesota': ['MN', 'minnesota'],
            'Mississippi': ['MS', 'mississippi'],
            'Missouri': ['MO', 'missouri'],
            'Montana': ['MT', 'montana'],
            'Nebraska': ['NE', 'nebraska'],
            'Nevada': ['NV', 'nevada'],
            'New Hampshire': ['NH', 'new hampshire'],
            'New Jersey': ['NJ', 'new jersey'],
            'New Mexico': ['NM', 'new mexico'],
            'New York': ['NY', 'new york'],
            'North Carolina': ['NC', 'north carolina'],
            'North Dakota': ['ND', 'north dakota'],
            'Ohio': ['OH', 'ohio'],
            'Oklahoma': ['OK', 'oklahoma'],
            'Oregon': ['OR', 'oregon'],
            'Pennsylvania': ['PA', 'pennsylvania'],
            'Rhode Island': ['RI', 'rhode island'],
            'South Carolina': ['SC', 'south carolina'],
            'South Dakota': ['SD', 'south dakota'],
            'Tennessee': ['TN', 'tennessee'],
            'Texas': ['TX', 'texas'],
            'Utah': ['UT', 'utah'],
            'Vermont': ['VT', 'vermont'],
            'Virginia': ['VA', 'virginia'],
            'Washington': ['WA', 'washington'],
            'West Virginia': ['WV', 'west virginia'],
            'Wisconsin': ['WI', 'wisconsin'],
            'Wyoming': ['WY', 'wyoming']
        },        
        'languages': {
            'english': ['english'],
            'spanish': ['spanish'],
            'french': ['french'],
            'german': ['german'],
            'chinese': ['chinese'],
            'portuguese': ['portuguese'],
            'arabic': ['arabic'],
            'hindi': ['hindi'],
            'russian': ['russian'],
            'japanese': ['japanese'],
            'italian': ['italian'],
            'korean': ['korean'],
            'dutch': ['dutch'],
            'turkish': ['turkish'],
            'swedish': ['swedish'],
            'polish': ['polish'],
            'greek': ['greek'],
            'romanian': ['romanian'],
            'hebrew': ['hebrew'],
        },
        'college degree': {
            'high school': ['high school', 'secondary school', 'hsc', 'highschool', 'secondary education'],
            'bachelor': ['undergrad', 'undergraduate', 'bachelor', 'bachelor\'s degree'],
            'masters': ['master', 'masters', 'graduate', 'master\'s degree', 'graduate degree'],
            'doctoral': ['doctorate', 'phd', 'doctor', 'doctoral', 'doctoral degree', 'doctoral studies'],
            'diploma': ['diploma', 'certificate', 'associate degree'],
        },    
        'SNS': {
            'social media': ['sns', 'social media', 'facebook', 'twitter', 'instagram', 'linkedin', 'tiktok', 'youtube', 'snapchat', 'pinterest'],
            #'non-social media': ['social network', 'online presence', 'profile']
        },       
        'religion': {
            'christianity': ['christian', 'christianity', 'jesus', 'bible', 'church', 'catholic', 'protestant', 'evangelical'],
            'islam': ['islam', 'muslim', 'quran', 'mosque', 'prophet muhammad', 'ramadan', 'sharia'],
            'judaism': ['jewish', 'judaism', 'torah', 'synagogue', 'rabbi'],
            'buddhism': ['buddhist', 'buddhism', 'buddha', 'samsara', 'nirvana', 'zen'],
            'hinduism': ['hindu', 'hinduism', 'karma', 'moksha', 'buddha', 'yoga', 'vedas'],
            'agnosticism': ['agnostic', 'agnosticism', 'uncertain', 'agnosticity'],
            'spirituality': ['spiritual', 'spirituality', 'spiritualism', 'new age', 'esoteric'],
            'atheism': ['atheist', 'atheism', 'godless', 'secular', 'non-believer'],
        },
        'marital status': {
            'married': ['married'],
            'single': ['single', 'unmarried'],
            'divorced': ['divorced', 'seperated'],
            'widowed': ['widowed'],
        },
        'profession': {
            'lawyer': ['lawyer', 'attorney', 'law', 'jurisprudence', 'court', 'litigation', 'legal counsel', 'barrister', 'solicitor'],
            'IT': ['IT', 'information technology', 'software engineer', 'developer', 'programmer', 'web developer', 'network administrator', 'system analyst', 'data scientist', 'cloud architect'],
            'doctor': ['doctor', 'physician', 'surgeon', 'healthcare', 'medical', 'nurse', 'doctorate', 'medical professional', 'healthcare provider'],
            'teacher': ['teacher', 'educator', 'professor', 'instructor', 'tutor', 'mentor', 'principal', 'lecturer'],
            'engineer': ['engineer', 'engineering', 'mechanical engineer', 'civil engineer', 'electrical engineer', 'aerospace engineer', 'chemical engineer', 'structural engineer'],
            'scientist': ['scientist', 'researcher', 'chemist', 'biologist', 'physicist', 'astronomer', 'laboratory', 'biotechnology', 'research scientist'],
            'artist': ['artist', 'painter', 'sculptor', 'designer', 'photographer', 'illustrator', 'visual artist', 'graphic designer'],
            'entrepreneur': ['entrepreneur', 'business owner', 'startup', 'founder', 'CEO', 'businessman', 'businesswoman', 'small business'],
            'writer': ['writer', 'author', 'journalist', 'novelist', 'content creator', 'blogger', 'editor'],
            'unemployed': ['unemployed', 'not working'],
            'self-employed': ['self-employed'],
        },        
        'income': {
            'lower class (<= $30,000)': ['income', 'salary', 'wage', 'earnings', 'pay', 'compensation', 'financial', 'how much do you earn', 'wealth', 'net worth', 'low income', 'poverty', 'minimum wage', 'below poverty line'],
            'lower-middle class ($30,001 - $58,020)': ['lower-middle class', 'working class', 'modest income', 'entry-level salary', 'starting salary', 'average wage', 'lower middle income'],
            'middle class ($58,021 - $94,000)': ['middle class', 'middle income', 'average income', 'moderate salary', 'moderate earnings', 'stable income', 'standard wage'],
            'upper-middle class ($94,001 - $153,000)': ['upper-middle class', 'upper middle income', 'higher salary', 'professional income', 'upper middle wage', 'well-off', 'comfortable income'],
            'upper class (> $153,000)': ['upper class', 'high income', 'luxury', 'six-figure salary', 'wealthy', 'millionaire', 'affluent', 'high earnings', 'top 1%', 'high net worth', 'elite income']
        },      
        'residence': {
            'single-family home': ['family', 'parents', 'children', 'siblings', 'spouse', 'partner', 'relatives', 'kin', 'descendants', 'ancestors', 'immediate family', 'extended family', 'single-family home', 'detached house', 'household'],
            'two-family home': ['two-family home', 'duplex', 'multi-generational', 'shared living', 'family unit', 'extended family living', 'home with multiple families'],
            'three-family home': ['three-family home', 'triplex', 'three-family residence', 'multiple-family home', 'three-generational family', 'family living together'],
            'apartment': ['apartment', 'condo', 'flat', 'studio', 'unit', 'rented apartment', 'apartment complex', 'shared apartment'],
            'shared housing': ['shared housing', 'housemates', 'roommates', 'co-living', 'boarding house', 'group housing'],
            'homeless': ['homeless'],
        }   
    }
    
   # Dynamically create labels in the defined order
    for category, subcategories in keyword_categories.items():
        category_labels = []  # To store subcategories that match the question
        
        if isinstance(subcategories, dict):  # If the category contains subcategories (like 'gender' and 'age')
            for subcategory, keywords in subcategories.items():
                if any(keyword in question for keyword in keywords):
                    category_labels.append(subcategory)  # Add the matched subcategory name
        
        # If no labels were added for this category, append 'N/A'
        if not category_labels:
            category_labels.append('N/A')

        # Add the matched category labels as a sublist
        labels.append(category_labels)

    # Fill up the labels list to ensure it has the required size
    labels_flat = labels[:label_size]  # Truncate if there are more than label_size labels
    labels_flat += [['N/A']] * (label_size - len(labels_flat))  # Add 'N/A' to make the list exactly 'label_size' long

    return labels_flat

# Load your CSV file
df = pd.read_csv('data_sample.csv')  # Ensure the path to your CSV is correct

# Apply the function to the 'question' column
df['labels'] = df['question'].apply(assign_labels)

# Save the DataFrame with the labels to a new CSV file
df.to_csv('output_with_labels.csv', index=False)

# Print the results
print(df[['question', 'labels']])
# Out:
#                                                question  \
# 0     In the mysterious world of FAR FAR AWAY, where...
# 1     In a parallel universe, both uncanny and perpl...
# 2     In the realm of the impossible, where the elus...
# 3     What is the name of the bizarre and surreal st...
# 4     In the enchanting world of magic where unicorn...
# ...                                                 ...
# 5939  Bilateral ovarian carcinoma + capsule + asciti...
# 5940  Question linked to the image nº20 Patient of 6...
# 5941  How is irregular or continuous uterine bleedin...
# 5942  Yellow fever is transmitted by a mosquito carr...
# 5943  When inhaled allergens, allergens by antigen p...
#
#                                                  labels
# 0     [[male, female], [N/A], [N/A], [indigenous], [...
# 1     [[male, female], [N/A], [N/A], [N/A], [usa], [...
# 2     [[male, female], [N/A], [N/A], [N/A], [usa], [...
# 3     [[male], [N/A], [N/A], [N/A], [usa], [N/A], [N...
# 4     [[male, female], [N/A], [N/A], [N/A], [N/A], [...
# ...                                                 ...
# 5939  [[N/A], [N/A], [N/A], [N/A], [N/A], [N/A], [N/...
# 5940  [[male], [N/A], [N/A], [N/A], [N/A], [N/A], [N...
# 5941  [[male], [N/A], [N/A], [N/A], [usa], [N/A], [N...
# 5942  [[N/A], [N/A], [N/A], [N/A], [N/A], [N/A], [N/...
# 5943  [[male, female], [N/A], [N/A], [N/A], [N/A], [...
#
# [5944 rows x 2 columns]

# %%
import os
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/saisirichittineni
